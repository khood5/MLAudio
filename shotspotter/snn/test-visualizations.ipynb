# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('./data/1200-dwt.npz')['train_set']

# %%
plt.figure(figsize=(25,5))
plt.pcolormesh(data, cmap='RdYlGn')

# %%
data = np.load('./data/1200-dwt-gs-1350.npz')['train_set'][448]

# %%
plt.figure(figsize=(25,5))
plt.pcolormesh(data, cmap='RdYlGn')

# %%
data = np.load('./data/1200-dwt.npz')['train_set'][925]
plt.figure(figsize=(25,5))
plt.pcolormesh(data, cmap='RdYlGn')
