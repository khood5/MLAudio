# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('./test450timesteps.npz')['channels']

# %%
plt.figure(figsize=(25,5))
plt.pcolormesh(data, cmap='RdYlGn')

# %%
data = np.load('./data/120-spec-25bins.npz')['train_set'][10]

# %%
plt.figure(figsize=(25,5))
plt.pcolormesh(data, cmap='RdYlGn')
