# %% [markdown]
# # Visualization for log outputs of SNNTorch training runs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_log(path):
    with open(path, 'r') as f:
        data = [[float(entry.replace('\n', '')) for entry in line.split(',')] for line in f.readlines()]
    
    return np.array(data)

# %%
# load everything
all_data = []

RUN_COUNT = 18
BASE_PATH = './results/'

for i in range(RUN_COUNT):
    l = load_log(BASE_PATH+str(i)+'/log.csv')
    all_data.append(l)

# %% [markdown]
# # Some runs on various datasets
# All of these use model size INPUTx100x100x2, LR=0.005 and batch size 128, with beta decay value 0.9

# %% [markdown]
# # Some Facts
# - Still have not changed the beta decay factor (it's at 0.9, i.e slow decay)
# - It does not look like the models (tried 1mil and 2mil param models) are memorizing the train set completely
#     - Validation and Train accuracy remain pretty close
# - Integrating the waveform doesnt seem to help (maybe it's not implemented correctly?)
# - Haven't tried more FCN layers
# - Have not tried new encoding on EONS

# %% [markdown]
# ### 5k Samples FFT spectrogram using Pos-Neg Delta Modulation
# Normalized globally (using min and max from all samples), DM threshold is 0.001

# %%
INDEX = 1

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 5k Samples FFT spectrogram using Pos-Neg Delta Modulation WITH Waveform data
# Normalized globally (using min and max from all samples), DM threshold is 0.001

# %%
INDEX = 2

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 2.4k Samples FFT spectrogram using Pos-Neg Delta Modulation
# Normalized **per sample** (using min and max per samples), DM threshold is 0.001

# %%
INDEX = 3

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 10k Samples FFT spectrogram using Pos-Neg Delta Modulation
# Normalized **per sample** (using min and max per samples), DM threshold is 0.001

# %%
INDEX = 4

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 10k Samples DWT using Pos-Neg Delta Modulation
# Normalized **per sample** (using min and max per samples), DM threshold is 0.001

# %%
INDEX = 5

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 5k FFT spectrogram using Pos-Neg Delta Modulation WITH Waveform
# Normalized **globally** (using min and max out of all samples), DM threshold is 0.001

# %%
INDEX = 6

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 5k FFT spectrogram using Pos-Neg Delta Modulation (smaller dm threshold)
# Normalized **globally** (using min and max out of all samples), DM threshold is **0.0001**
#
# Picked best model out of all from before, reduced delta mod threshold. Reasoning is that with the 0.001 threshold, about 15% of our samples were spking less than 10 times total (because their intensity values in the spectrogram are very small, since we normalized globally). After lowering delta mod, this number reduces to 4%.

# %%
INDEX = 7

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 5k FFT spectrogram using Pos-Neg Delta Modulation (smaller dm threshold + larger model)
# Normalized **globally** (using min and max out of all samples), DM threshold is **0.0001**
#
# Increased model to inputx150x150x2 (roughly 2.2x param count)

# %%
INDEX = 9

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 10k DWT using Pos-Neg Delta Modulation (larger model)
# Normalized **per sample**, DM threshold is **0.05**
#
# Increased model to inputx150x150x2 (roughly 2.2x param count)

# %%
INDEX = 10

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 10k DWT using Pos-Neg Delta Modulation (larger model, beta factor changed to 0.5)
# Normalized **per sample**, DM threshold is **0.05**
#
# Increased model to inputx150x150x2 (roughly 2.2x param count)

# %%
INDEX = 11

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# 290.0614484548569

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (20x model size)
# Normalized **per sample**, DM threshold is **0.05**
#
# Increased model to inputx800x800x2 (670k params)
# Weight decay 1e-4

# %%
INDEX = 16

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
print(all_data[INDEX][:, 1].min())
# Out:
# 259.69794165715575

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')
#plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), [84.5 for i in range(len(all_data[INDEX]))])
max(all_data[INDEX][:, 2])
# Out:
# np.float64(87.67500305175781)

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (20x model size, +1 layer)
# Normalized **per sample**, DM threshold is **0.05**
#
# Increased model to inputx800x400x200x2 (~400k params)
# No Weight Decay

# %%
INDEX = 17

plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), all_data[INDEX][:, 2], color='purple')
#plt.plot(np.linspace(0, len(all_data[INDEX]), len(all_data[INDEX])), [84.5 for i in range(len(all_data[INDEX]))])
max(all_data[INDEX][:, 2])
# Out:
# np.float64(87.85000610351562)

# %% [markdown]
# # Convolutional LSTM model

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation
# Normalized **per sample**, DM threshold is **0.05**
#
# No weight decay. LR=0.0003, threshold=0.17,
# architecture:
# Conv 1 -> 16, K=5
# Conv 16 -> 32, K=3
# Conv 32 -> 64, K=3
# FCN 1536x128x2

# %%
temp = load_log('./results/scorp-conv/2/log.csv')

# %%
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Convolutional Spiking LSTM Losses')
# Out:
# Text(0.5, 1.0, 'Convolutional Spiking LSTM Losses')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 2], color='purple')
plt.title('Convolutional Spiking LSTM Val Accuracy')
temp[:, 2].max()
# Out:
# np.float64(85.77500915527344)

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (With adam weight decay 1e-6)
# Normalized **per sample**, DM threshold is **0.05**
#
# No weight decay. LR=0.0003, threshold=0.17,
# architecture:
# Conv 1 -> 16, K=5
# Conv 16 -> 32, K=3
# Conv 32 -> 64, K=3
# FCN 1536x128x2

# %%
temp = load_log('./results/reac-conv/0/log.csv')

# %%
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Convolutional Spiking LSTM Losses')
# Out:
# Text(0.5, 1.0, 'Convolutional Spiking LSTM Losses')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 2], color='purple')
plt.title('Convolutional Spiking LSTM Val Accuracy')
temp[:, 2].max()
# Out:
# np.float64(84.5250015258789)

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (With adamW weight decay 1e-5)
# **NOTE: changed from adam to adamW implementation**
#
# Normalized **per sample**, DM threshold is **0.05**
#
# No weight decay. LR=0.0003, threshold=0.17,
# architecture:
# Conv 1 -> 16, K=5
# Conv 16 -> 32, K=3
# Conv 32 -> 64, K=3
# FCN 1536x128x2

# %%
temp = load_log('./results/reac-conv/1/log.csv')

# %%
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Convolutional Spiking LSTM Losses')
# Out:
# Text(0.5, 1.0, 'Convolutional Spiking LSTM Losses')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 2], color='purple')
plt.title('Convolutional Spiking LSTM Val Accuracy')
temp[:, 2].max()
# Out:
# np.float64(86.12500762939453)

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (With adamW weight decay 1e-4)
# **NOTE: changed from adam to adamW implementation**
#
# Normalized **per sample**, DM threshold is **0.05**
#
# No weight decay. LR=0.0003, threshold=0.17,
# architecture:
# Conv 1 -> 16, K=5
# Conv 16 -> 32, K=3
# Conv 32 -> 64, K=3
# FCN 1536x128x2

# %%
temp = load_log('./results/reac-conv/2/log.csv')

# %%
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Convolutional Spiking LSTM Losses')
# Out:
# Text(0.5, 1.0, 'Convolutional Spiking LSTM Losses')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 2], color='purple')
plt.title('Convolutional Spiking LSTM Val Accuracy')
temp[:, 2].max()
# Out:
# np.float64(85.47500610351562)

# %% [markdown]
# ### 40k DWT using Pos-Neg Delta Modulation (With adamW weight decay 1e-2)
# **NOTE: changed from adam to adamW implementation**
#
# Normalized **per sample**, DM threshold is **0.05**
#
# No weight decay. LR=0.0003, threshold=0.17,
# architecture:
# Conv 1 -> 16, K=5
# Conv 16 -> 32, K=3
# Conv 32 -> 64, K=3
# FCN 1536x128x2

# %%
temp = load_log('./results/reac-conv/3/log.csv')

# %%
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 0], label='Train Loss')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 1], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Convolutional Spiking LSTM Losses')
# Out:
# Text(0.5, 1.0, 'Convolutional Spiking LSTM Losses')

# %%
plt.title('Validation set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.plot(np.linspace(0, len(temp), len(temp)), temp[:, 2], color='purple')
plt.title('Convolutional Spiking LSTM Val Accuracy')
temp[:, 2].max()
# Out:
# np.float64(85.5)
