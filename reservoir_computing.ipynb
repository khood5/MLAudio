# %%
import numpy as np
from typing import Any

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class esn:
    def __init__(self) -> None:
        pass

    def __call__(self, *args: Any, **kwds: Any) -> Any:
        pass

    def train(self):
        pass

    def run_reservoir(self):
        pass

# %% [markdown]
# The linear regression method works as follows
#     1. Once all the states for a given example input series have been calculated, i.e. the state matrix X is complete and of shape N x K.
#     2. Then minimize the mean square error of the linear mapping of X to T
#
# ![image.png](attachment:image.png)
#
# Which can be turned into
#
# ![image-2.png](attachment:image-2.png)
#
# Which is our pseudo inverse matrix method
#
# The below is the moore penrose generalized inverse formula a.k.a pinv in many python libraires
#
# ![image-3.png](attachment:image-3.png)
